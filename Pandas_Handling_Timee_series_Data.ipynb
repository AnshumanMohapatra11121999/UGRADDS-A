# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshumanMohapatra11121999/UGRADDS-A/blob/main/Pandas_Handling_Timee_series_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Time-series data refers to a series of data points indexed over time.
The data is recorded over regular time intervals and stored along with the time of collection. Common examples of time series include stock prices, temperature, weather reports, etc.,
as this information would make sense only when presented with the time they were recorded.
'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
weather=pd.read_csv("/content/weather_data.csv")

# %%
weather
# Out:
#       Temperature  DewPoint  Pressure       Date_Time
# 0            46.2      37.5         1  20100101 00:00
# 1            44.6      37.1         1  20100101 01:00
# 2            44.1      36.9         1  20100101 02:00
# 3            43.8      36.9         1  20100101 03:00
# 4            43.5      36.8         1  20100101 04:00
# ...           ...       ...       ...             ...
# 8754         51.1      38.1         1  20101231 19:00
# 8755         49.0      37.9         1  20101231 20:00
# 8756         47.9      37.9         1  20101231 21:00
# 8757         46.9      37.9         1  20101231 22:00
# 8758         46.2      37.7         1  20101231 23:00
#
# [8759 rows x 4 columns]

# %%
#Date time column is in string formt we have to convert it into date and time format
#parse_dates() method changes string data type to date and time data type

# %%
weather=pd.read_csv("/content/weather_data.csv",parse_dates=["Date_Time"])

# %%
weather
# Out:
#       Temperature  DewPoint  Pressure           Date_Time
# 0            46.2      37.5         1 2010-01-01 00:00:00
# 1            44.6      37.1         1 2010-01-01 01:00:00
# 2            44.1      36.9         1 2010-01-01 02:00:00
# 3            43.8      36.9         1 2010-01-01 03:00:00
# 4            43.5      36.8         1 2010-01-01 04:00:00
# ...           ...       ...       ...                 ...
# 8754         51.1      38.1         1 2010-12-31 19:00:00
# 8755         49.0      37.9         1 2010-12-31 20:00:00
# 8756         47.9      37.9         1 2010-12-31 21:00:00
# 8757         46.9      37.9         1 2010-12-31 22:00:00
# 8758         46.2      37.7         1 2010-12-31 23:00:00
#
# [8759 rows x 4 columns]

# %%
#Lets make the datetime column as index column and check whether the dataframe has a column of date and time datatype or not
weather=pd.read_csv("/content/weather_data.csv",parse_dates=True,index_col="Date_Time")

# %%
weather
# Out:
#                      Temperature  DewPoint  Pressure
# Date_Time
# 2010-01-01 00:00:00         46.2      37.5         1
# 2010-01-01 01:00:00         44.6      37.1         1
# 2010-01-01 02:00:00         44.1      36.9         1
# 2010-01-01 03:00:00         43.8      36.9         1
# 2010-01-01 04:00:00         43.5      36.8         1
# ...                          ...       ...       ...
# 2010-12-31 19:00:00         51.1      38.1         1
# 2010-12-31 20:00:00         49.0      37.9         1
# 2010-12-31 21:00:00         47.9      37.9         1
# 2010-12-31 22:00:00         46.9      37.9         1
# 2010-12-31 23:00:00         46.2      37.7         1
#
# [8759 rows x 3 columns]

# %%
weather.index.name
# Out:
# 'Date_Time'

# %%
weather.index.name = None

# %%
weather#TO remove the index column header
# Out:
#                      Temperature  DewPoint  Pressure
# 2010-01-01 00:00:00         46.2      37.5         1
# 2010-01-01 01:00:00         44.6      37.1         1
# 2010-01-01 02:00:00         44.1      36.9         1
# 2010-01-01 03:00:00         43.8      36.9         1
# 2010-01-01 04:00:00         43.5      36.8         1
# ...                          ...       ...       ...
# 2010-12-31 19:00:00         51.1      38.1         1
# 2010-12-31 20:00:00         49.0      37.9         1
# 2010-12-31 21:00:00         47.9      37.9         1
# 2010-12-31 22:00:00         46.9      37.9         1
# 2010-12-31 23:00:00         46.2      37.7         1
#
# [8759 rows x 3 columns]

# %%
#Extract data for different date and times
weather.loc["February 5,2010"]
# Out:
#                      Temperature  DewPoint  Pressure
# 2010-02-05 00:00:00         48.2      40.9         1
# 2010-02-05 01:00:00         47.2      41.0         1
# 2010-02-05 02:00:00         46.5      40.6         1
# 2010-02-05 03:00:00         45.9      40.4         1
# 2010-02-05 04:00:00         45.4      39.9         1
# 2010-02-05 05:00:00         44.9      39.5         1
# 2010-02-05 06:00:00         45.3      39.6         1
# 2010-02-05 07:00:00         44.3      39.1         1
# 2010-02-05 08:00:00         44.8      39.5         1
# 2010-02-05 09:00:00         48.0      40.8         1
# 2010-02-05 10:00:00         51.0      41.0         1
# 2010-02-05 11:00:00         54.0      41.0         1
# 2010-02-05 12:00:00         56.1      40.7         1
# 2010-02-05 13:00:00         58.1      40.9         1
# 2010-02-05 14:00:00         59.6      40.8         1
# 2010-02-05 15:00:00         60.4      40.7         1
# 2010-02-05 16:00:00         60.5      40.4         1
# ...

# %%
weather.loc["2010-10-11 9:00:00":"2010-10-11 22:00:00"]
# Out:
#                      Temperature  DewPoint  Pressure
# 2010-10-11 09:00:00         69.8      60.7         1
# 2010-10-11 10:00:00         73.5      60.7         1
# 2010-10-11 11:00:00         76.4      60.2         1
# 2010-10-11 12:00:00         78.5      59.4         1
# 2010-10-11 13:00:00         80.3      59.1         1
# 2010-10-11 14:00:00         81.5      58.7         1
# 2010-10-11 15:00:00         82.0      58.5         1
# 2010-10-11 16:00:00         81.7      58.2         1
# 2010-10-11 17:00:00         80.6      58.2         1
# 2010-10-11 18:00:00         77.2      58.7         1
# 2010-10-11 19:00:00         73.1      59.5         1
# 2010-10-11 20:00:00         70.6      59.6         1
# 2010-10-11 21:00:00         69.0      59.8         1
# 2010-10-11 22:00:00         67.7      59.9         1

# %%
weather.loc["2010-12-15":"2010-12-31"]
# Out:
#                      Temperature  DewPoint  Pressure
# 2010-12-15 00:00:00         48.0      40.5         1
# 2010-12-15 01:00:00         47.2      40.3         1
# 2010-12-15 02:00:00         46.5      40.0         1
# 2010-12-15 03:00:00         46.0      39.7         1
# 2010-12-15 04:00:00         45.6      39.5         1
# ...                          ...       ...       ...
# 2010-12-31 19:00:00         51.1      38.1         1
# 2010-12-31 20:00:00         49.0      37.9         1
# 2010-12-31 21:00:00         47.9      37.9         1
# 2010-12-31 22:00:00         46.9      37.9         1
# 2010-12-31 23:00:00         46.2      37.7         1
#
# [408 rows x 3 columns]

# %%
#Let's try to draw a line plot for temperature during December in Austin City.

# %%
'''Moving further,
let us learn how to analyse a time series visually. If you recall from the last session on Matplotlib, a line plot is the best plot to analyse data over time as it reflects the trend over the desired time frame.
Let's try to draw a line plot for temperature during December in Austin City.'''

# %%
dec = weather.loc["2010-12-15":"2010-12-31"]
dec[["Temperature"]].plot(kind = "line")
plt.show()
