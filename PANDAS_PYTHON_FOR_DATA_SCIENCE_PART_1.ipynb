# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshumanMohapatra11121999/UGRADDS-A/blob/main/PANDAS_PYTHON_FOR_DATA_SCIENCE_PART_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
'''Creating dataframes
Importing CSV data files as Pandas dataframes
Reading and summarising dataframes
Sorting dataframes
Labelling, indexing and slicing data
Merging dataframes using joins
Pivoting and grouping'''
# Out:
# 'Creating dataframes\nImporting CSV data files as Pandas dataframes\nReading and summarising dataframes\nSorting dataframes\nLabelling, indexing and slicing data\nMerging dataframes using joins\nPivoting and grouping'

# %%
'''There are two main data structures in Pandas:
Series- 1D ARRAY CAPABLE OF HOLDING MULTIPLE DATA TYPES
Dataframes -2D HETEROGENEOUS DATA STRUCTURE WHICH INCLUDES ROWS AND COLUMN '''
# Out:
# 'There are two main data structures in Pandas: \nSeries- 1D ARRAY CAPABLE OF HOLDING MULTIPLE DATA TYPES\nDataframes -2D HETEROGENEOUS DATA STRUCTURE WHICH INCLUDES ROWS AND COLUMN '

# %%
#The most basic object in Pandas is a Series.
#To visualise it easily, a series can be thought of as a one-dimensional (1D) NumPy array with a label and an index attached to it.
#Also, unlike NumPy arrays, they can contain non-numeric data (characters, dates, time, booleans, etc.).
#Usually, you will work with Series only as part of dataframes

# %%
#You could create a Pandas series from an array-like object using the following command:
#pd.Series(data, dtype)

# %%
'''A dataframe is the most widely used data structure in data analysis.
It is a table with rows and columns, with rows having an index each and columns having meaningful names.
There are various ways of creating dataframes, for instance, creating them from dictionaries, reading from .txt and .csv files, etc.
Let’s take a look at them one by one'''
# Out:
# 'A dataframe is the most widely used data structure in data analysis.\nIt is a table with rows and columns, with rows having an index each and columns having meaningful names.\nThere are various ways of creating dataframes, for instance, creating them from dictionaries, reading from .txt and .csv files, etc. \nLet’s take a look at them one by one'

# %%
'''Creating dataframes from dictionaries
_______________________________________________
If you have data in the form of lists in Python,
you can create the dataframe directly through dictionaries.
The ‘key’ in the dictionary acts as the column name,
and the ‘values’ stored are the entries under the column.'''
# Out:
# 'Creating dataframes from dictionaries\n_______________________________________________\nIf you have data in the form of lists in Python, \nyou can create the dataframe directly through dictionaries.\nThe ‘key’ in the dictionary acts as the column name, \nand the ‘values’ stored are the entries under the column.'

# %%
## Python Libraries - Pandas - Pandas Basics
#Pandas is a library built using NumPy specifically for data analysis. You'll be using Pandas heavily for data manipulation, visualisation, building machine learning models, etc.

#There are two main data structures in Pandas:
#- Series
#- Dataframes

#The default way to store data is dataframes, and thus manipulating dataframes quickly is probably the most important skill set for data analysis.
# import pandas, pd is an alias

### The Pandas Series

#A series is similar to a 1-D numpy array, and contains scalar values of the same type (numeric, character, datetime etc.).
#A dataframe is simply a table where each column is a pandas series.

# Creating a numeric pandas series
s = pd.Series([2, 4, 5, 6, 9])
print(s)
print(type(s))
# creating a series of type datetime
date_series = pd.date_range(start = '11-09-2017', end = '12-12-2017')
date_series
type(date_series)
#Note that each element in the Series has an index, and the index starts at 0 as usual.
# Out:
# 0    2
# 1    4
# 2    5
# 3    6
# 4    9
# dtype: int64
# <class 'pandas.core.series.Series'>
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
### The Pandas Dataframe

#Dataframe is the most widely used data-structure in data analysis. It is a table with rows and columns, with rows having an index and columns having meaningful names.

#There are various ways of creating dataframes, such as creating them from dictionaries, JSON objects, reading from txt, CSV files, etc.
#### Creating dataframes from dictionaries
# Defining data to create lists for dictionary
cars_per_cap = [809, 731, 588, 18, 200, 70, 45]
country = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
drives_right = [False, True, True, True, False, False, False]
# Creating the dictionaries to store the entries as key-value pair.
cars_dict = {"cars_per_cap" : cars_per_cap, "country" : country, "drives_right" : drives_right }

# Create the dataframe 'cars'
cars = pd.DataFrame(cars_dict)
# print the created dataframe
cars
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States         False
# 1           731      Australia          True
# 2           588          Japan          True
# 3            18          India          True
# 4           200         Russia         False
# 5            70        Morocco         False
# 6            45          Egypt         False

# %%
#### Importing CSV data files as pandas dataframes

'''For the upcoming exercises, we will use a car dataset which holds the following information:

- Region Code
- Country
- Coutry Code
- Car per capita
- Drives Right'''
# read the data from the csv file
cars = pd.read_csv("/content/cars.csv")

# check the dataframe created
cars
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True
# 3  ASPAC   RU        Russia  200.0  False
# 4  LATAM  MOR       Morocco   70.0  False
# 5    AFR   EG         Egypt   45.0  False
# 6    EUR  ENG       England    NaN   True

# %%
#As you can see from the dataframe above, the first row has been taken as the column header for the dataframe. Let's see how to prevent that.
# load the dataframe from the csv without any header
cars = pd.read_csv("/content/cars.csv",header=None)

# check the dataframe created
cars
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
#Now, the columns have the labels as 0, 1, 2, etc.
#The top row is now considered as a part of the row entries.

# %%
## Python Libraries - Pandas - Rows and Columns
### Indices and Labels
#### Indices

'''An important concept in pandas dataframes is that of *row indices*. By default, each row is assigned indices starting from 0, and are represented at the left side of the dataframe.

Now, arbitrary numeric indices are difficult to read and work with. Thus, you may want to change the indices of the dataframe to something more meanigful.

Let's change the index to the second column which stores the country codes, so that you can select rows using the country code directly.'''
# load the data into a dataframe with no header and index column as the second column
cars = pd.read_csv("/content/cars.csv",header=None,index_col = 1)
#Index column attribute makes the particulae column the row header
# Check the created dataframe
cars
# Out:
#          0              2      3      4
# 1
# US    USCA  United States  809.0  False
# AUS  ASPAC      Australia  731.0   True
# JAP  ASPAC          Japan  588.0   True
# IN   ASPAC          India   18.0   True
# RU   ASPAC         Russia  200.0  False
# MOR  LATAM        Morocco   70.0  False
# EG     AFR          Egypt   45.0  False
# ENG    EUR        England    NaN   True

# %%
# Print the label of the index column
cars.index.name
# Out:
# 1

# %%
# Remove the label of the index column( the index column is a special column that labels each row of the DataFrame. It serves as an identifier for each row, allowing for easy access and manipulation of data. The index column is often used for various operations such as selection, joining, and grouping data.)
cars.reset_index(drop=True, inplace=True)
# Check the created dataframe
cars

#Having meaningful row labels as indices helps you to select (subset) dataframes easily. You will study selecting dataframes in the next section. Let's now try to change the column headers.
# Out:
#   Region code      Countries  Car per capita  Drives Right
# 0        USCA  United States           809.0         False
# 1       ASPAC      Australia           731.0          True
# 2       ASPAC          Japan           588.0          True
# 3       ASPAC          India            18.0          True
# 4       ASPAC         Russia           200.0         False
# 5       LATAM        Morocco            70.0         False
# 6         AFR          Egypt            45.0         False
# 7         EUR        England             NaN          True

# %%
cars.columns
# Out:
# Index(['Region code', 'Countries', 'Car per capita', 'Drives Right'], dtype='object')

# %%
#### Column headers
cars.columns=["Region code","Countries","Car per capita","Drives Right"]
# Print the column headers of the dataframe
cars
# Out:
#   Region code      Countries  Car per capita  Drives Right
# 0        USCA  United States           809.0         False
# 1       ASPAC      Australia           731.0          True
# 2       ASPAC          Japan           588.0          True
# 3       ASPAC          India            18.0          True
# 4       ASPAC         Russia           200.0         False
# 5       LATAM        Morocco            70.0         False
# 6         AFR          Egypt            45.0         False
# 7         EUR        England             NaN          True

# %%
#You can use the following code to change the row indices:

#dataframe_name.index
cars.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
# Change the label of each column


# Check the created dataframe

#Without the labels, it will be very difficult to remember the information stored in the columns.
#Now you can easily make sense from the entries stored in the dataframe. Let's now try to define multiple indices in a dataframe.
#### Multi-indexing in Pandas
# Import the data from a csv file with multiple indices
carsmi = pd.read_csv("/content/cars.csv",header=None,index_col=[0,1])
#Here we are making both oth and 1st column as index column for multiple or hierarchial indexing

# Check the created dataframe
carsmi
# Out:
#                        2      3      4
# 0     1
# USCA  US   United States  809.0  False
# ASPAC AUS      Australia  731.0   True
#       JAP          Japan  588.0   True
#       IN           India   18.0   True
#       RU          Russia  200.0  False
# LATAM MOR        Morocco   70.0  False
# AFR   EG           Egypt   45.0  False
# EUR   ENG        England    NaN   True

# %%
#Chnage the name of the column headers
carsmi.columns=["Countries","Car per capita","Drives Right"]
carsmi
# Out:
#                Countries  Car per capita  Drives Right
# 0     1
# USCA  US   United States           809.0         False
# ASPAC AUS      Australia           731.0          True
#       JAP          Japan           588.0          True
#       IN           India            18.0          True
#       RU          Russia           200.0         False
# LATAM MOR        Morocco            70.0         False
# AFR   EG           Egypt            45.0         False
# EUR   ENG        England             NaN          True

# %%
#cars.index.names returns the name of the index column header
print(carsmi.index.names)
# Out:
# [0, 1]

# %%
#Change the index column name or header
carsmi.index.names=["Region code","Country code"]
carsmi
# Out:
#                               Countries  Car per capita  Drives Right
# Region code Country code
# USCA        US            United States           809.0         False
# ASPAC       AUS               Australia           731.0          True
#             JAP                   Japan           588.0          True
#             IN                    India            18.0          True
#             RU                   Russia           200.0         False
# LATAM       MOR                 Morocco            70.0         False
# AFR         EG                    Egypt            45.0         False
# EUR         ENG                 England             NaN          True

# %%
# Check the created dataframe

# Print the inforamtion of the index in the dataframe

#Multi-indexing is very useful to establish a hierarchy in the entries.
#It helps to segregate data into different categories and makes it easier to analyse the data.

# %%
import pandas as pd

# %%
sales = pd.read_excel("/content/sales.xlsx")
sales
# Out:
#           Market             Region  No_of_Orders    Profit      Sales
# 0         Africa     Western Africa           251 -12901.51   78476.06
# 1         Africa    Southern Africa            85  11768.58   51319.50
# 2         Africa       North Africa           182  21643.08   86698.89
# 3         Africa     Eastern Africa           110   8013.04   44182.60
# 4         Africa     Central Africa           103  15606.30   61689.99
# 5   Asia Pacific       Western Asia           382 -16766.90  124312.24
# 6   Asia Pacific      Southern Asia           469  67998.76  351806.60
# 7   Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# 8   Asia Pacific            Oceania           646  54734.02  408002.98
# 9   Asia Pacific       Eastern Asia           414  72805.10  315390.77
# 10  Asia Pacific       Central Asia            37  -2649.76    8190.74
# 11        Europe     Western Europe           964  82091.27  656637.14
# ...

# %%
#Lets make region column the index column
sales = pd.read_excel("/content/sales.xlsx",index_col=1)
sales
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Western Africa           Africa           251 -12901.51   78476.06
# Southern Africa          Africa            85  11768.58   51319.50
# North Africa             Africa           182  21643.08   86698.89
# Eastern Africa           Africa           110   8013.04   44182.60
# Central Africa           Africa           103  15606.30   61689.99
# Western Asia       Asia Pacific           382 -16766.90  124312.24
# Southern Asia      Asia Pacific           469  67998.76  351806.60
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38
# Oceania            Asia Pacific           646  54734.02  408002.98
# Eastern Asia       Asia Pacific           414  72805.10  315390.77
# Central Asia       Asia Pacific            37  -2649.76    8190.74
# Western Europe           Europe           964  82091.27  656637.14
# Southern Europe          Europe           338  18911.49  215703.93
# ...

# %%
sales.head()
# Out:
#                  Market  No_of_Orders    Profit     Sales
# Region
# Western Africa   Africa           251 -12901.51  78476.06
# Southern Africa  Africa            85  11768.58  51319.50
# North Africa     Africa           182  21643.08  86698.89
# Eastern Africa   Africa           110   8013.04  44182.60
# Central Africa   Africa           103  15606.30  61689.99

# %%
sales.head(8)
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Western Africa           Africa           251 -12901.51   78476.06
# Southern Africa          Africa            85  11768.58   51319.50
# North Africa             Africa           182  21643.08   86698.89
# Eastern Africa           Africa           110   8013.04   44182.60
# Central Africa           Africa           103  15606.30   61689.99
# Western Asia       Asia Pacific           382 -16766.90  124312.24
# Southern Asia      Asia Pacific           469  67998.76  351806.60
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38

# %%
sales.tail()
# Out:
#             Market  No_of_Orders    Profit      Sales
# Region
# Western US    USCA           490  44303.65  251991.83
# Southern US   USCA           255  19991.83  148771.91
# Eastern US    USCA           443  47462.04  264973.98
# Central US    USCA           356  33697.43  170416.31
# Canada        USCA            49   7246.62   26298.81

# %%
sales.tail(8)
# Out:
#                 Market  No_of_Orders    Profit      Sales
# Region
# South America    LATAM           496  12377.59  210710.49
# Central America  LATAM           930  74679.54  461670.28
# Caribbean        LATAM           288  13529.59  116333.05
# Western US        USCA           490  44303.65  251991.83
# Southern US       USCA           255  19991.83  148771.91
# Eastern US        USCA           443  47462.04  264973.98
# Central US        USCA           356  33697.43  170416.31
# Canada            USCA            49   7246.62   26298.81

# %%
sales.info()#To get complete information about the dataframe
'''dataframe.info(): This method prints information about the dataframe,
 which includes the index data type and column data types,
  the count of non-null values and the memory used.'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, Western Africa to Canada
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Market        23 non-null     object
#  1   No_of_Orders  23 non-null     int64
#  2   Profit        23 non-null     float64
#  3   Sales         23 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 920.0+ bytes
# 'dataframe.info(): This method prints information about the dataframe,\n which includes the index data type and column data types,\n  the count of non-null values and the memory used.'

# %%
sales.describe()#get statistical information of the dataframe
'''dataframe.describe(): This function produces descriptive statistics for the dataframe, that is,
 the central tendency (mean, median, min, max, etc.),
 dispersion, etc. It analyses the data and generates output for numeric and non-numeric data types accordingly.'''
# Out:
# 'dataframe.describe(): This function produces descriptive statistics for the dataframe, that is,\n the central tendency (mean, median, min, max, etc.), \n dispersion, etc. It analyses the data and generates output for numeric and non-numeric data types accordingly.'

# %%
#standard deviation measures the spread of the data area
#Low sd means the data points are tends to be closer to the mean but  a higher one indicates that the datapoints are scattered over a large range of area in the plan
#Higher sd also indicates the presence of outliers in the data points
#Outliers are those data point which differs from other usual datapoints and can create unusual observation in your data analysis

# %%
#As we have noticed the sales data set has higher standard deviation which also indicates the presence of outliers
#lets find them using box plot
import matplotlib.pyplot as plt
sales[["Profit","Sales"]].plot(kind = "box",subplots = True)
plt.show()

# %%
#In the above graph we can see that there is an outlier present in sales column  boxplot
#So the sd was coming more than the column profit
#And the green line shows the mean where the lines above and below mean line shows the 75% and 25% of the data points respectively
#The line below and above the box shows the iqr(inter quardial range)

# %%
sales.columns
# Out:
# Index(['Market', 'No_of_Orders', 'Profit', 'Sales'], dtype='object')

# %%
sales.shape
# Out:
# (23, 4)

# %%
#Indexing and Slicing
'''
Select rows from a dataframe.
Select columns from a dataframe.
Select subsets of dataframes.
'''
#The selection of rows in dataframes is similar to the indexing you saw in NumPy arrays.
#The syntax df[start_index:end_index] will subset the rows according to the start and end indices.

# %%
sales[["Profit"]]#When you use double square bracket it returns a dataframe like this output below.
# Out:
#                      Profit
# Region
# Western Africa    -12901.51
# Southern Africa    11768.58
# North Africa       21643.08
# Eastern Africa      8013.04
# Central Africa     15606.30
# Western Asia      -16766.90
# Southern Asia      67998.76
# Southeastern Asia  20948.84
# Oceania            54734.02
# Eastern Asia       72805.10
# Central Asia       -2649.76
# Western Europe     82091.27
# Southern Europe    18911.49
# Northern Europe    43237.44
# Eastern Europe     25050.69
# South America      12377.59
# Central America    74679.54
# Caribbean          13529.59
# Western US         44303.65
# Southern US        19991.83
# Eastern US         47462.04
# Central US         33697.43
# Canada              7246.62

# %%
sales["Profit"]#If we use single square bracket it returns series like the below output
# Out:
# Region
# Western Africa      -12901.51
# Southern Africa      11768.58
# North Africa         21643.08
# Eastern Africa        8013.04
# Central Africa       15606.30
# Western Asia        -16766.90
# Southern Asia        67998.76
# Southeastern Asia    20948.84
# Oceania              54734.02
# Eastern Asia         72805.10
# Central Asia         -2649.76
# Western Europe       82091.27
# Southern Europe      18911.49
# Northern Europe      43237.44
# Eastern Europe       25050.69
# South America        12377.59
# Central America      74679.54
# Caribbean            13529.59
# Western US           44303.65
# Southern US          19991.83
# Eastern US           47462.04
# Central US           33697.43
# Canada                7246.62
# Name: Profit, dtype: float64

# %%
sales[["Profit","Sales"]]
# Out:
#                      Profit      Sales
# Region
# Western Africa    -12901.51   78476.06
# Southern Africa    11768.58   51319.50
# North Africa       21643.08   86698.89
# Eastern Africa      8013.04   44182.60
# Central Africa     15606.30   61689.99
# Western Asia      -16766.90  124312.24
# Southern Asia      67998.76  351806.60
# Southeastern Asia  20948.84  329751.38
# Oceania            54734.02  408002.98
# Eastern Asia       72805.10  315390.77
# Central Asia       -2649.76    8190.74
# Western Europe     82091.27  656637.14
# Southern Europe    18911.49  215703.93
# Northern Europe    43237.44  252969.09
# Eastern Europe     25050.69  108258.93
# South America      12377.59  210710.49
# Central America    74679.54  461670.28
# Caribbean          13529.59  116333.05
# Western US         44303.65  251991.83
# Southern US        19991.83  148771.91
# Eastern US         47462.04  264973.98
# Central US         33697.43  170416.31
# Canada              7246.62   26298.81

# %%
'''
df['column'] or df.column: It returns a series
df[['col_x', 'col_y']]: It returns a dataframe
'''
# Out:
# "\ndf['column'] or df.column: It returns a series\ndf[['col_x', 'col_y']]: It returns a dataframe\n"

# %%
#Fetch data row wise
sales.loc["Canada"]
# Out:
# Market              USCA
# No_of_Orders          49
# Profit           7246.62
# Sales           26298.81
# Name: Canada, dtype: object

# %%
sales.loc[["Canada","Western Africa"]]
# Out:
#                 Market  No_of_Orders    Profit     Sales
# Region
# Canada            USCA            49   7246.62  26298.81
# Western Africa  Africa           251 -12901.51  78476.06

# %%
#dataframe.loc[[list_of_row_labels], [list_of_column_labels]] use this inorder to get values of particular column in a particular row
sales.loc[["Canada","Western Africa"],["Profit","Sales"]]
# Out:
#                   Profit     Sales
# Region
# Canada           7246.62  26298.81
# Western Africa -12901.51  78476.06

# %%
#This is called label-based indexing over dataframes. Now, you may face some challenges while dealing with the labels

# %%
sales.iloc[0:5,2:4]
#dataframe.iloc[rows, columns]
# Out:
#                    Profit     Sales
# Region
# Western Africa  -12901.51  78476.06
# Southern Africa  11768.58  51319.50
# North Africa     21643.08  86698.89
# Eastern Africa    8013.04  44182.60
# Central Africa   15606.30  61689.99

# %%
'''another method for indexing a dataframe is the iloc method, which uses the row or column number instead of labels:

dataframe.iloc[rows, columns]


Since we use positions instead of labels to extract values from the dataframe, it is called position-based indexing. You can easily extract the required entries from a dataframe based on their labels or positions with these two methods.'''

# %%
#Subsetting Rows Based on Conditions
'''
Often, you want to select rows that satisfy some given conditions. For example,
you may want to select all orders where Sales > 3,000, or all orders where 2,000 < Sales < 3,000 and Profit < 100.
Arguably, the best way to perform these operations is to use df.loc[], since df.iloc[] would require you to remember the integer column indices, which is tedious.
Let’s start first with one condition to filter the elements in the dataframe.'''

# %%
import pandas as pd

# %%
#condition:lets get the values of the rows where the proif is positive for the respective region
sales[["Profit"]]>0
# Out:
#                    Profit
# Region
# Western Africa      False
# Southern Africa      True
# North Africa         True
# Eastern Africa       True
# Central Africa       True
# Western Asia        False
# Southern Asia        True
# Southeastern Asia    True
# Oceania              True
# Eastern Asia         True
# Central Asia        False
# Western Europe       True
# Southern Europe      True
# Northern Europe      True
# Eastern Europe       True
# South America        True
# Central America      True
# Caribbean            True
# Western US           True
# Southern US          True
# Eastern US           True
# Central US           True
# Canada               True

# %%
sales[sales["Profit"]>0]#Doubt :I have only specified to display profit column why it is showing all the columns???
# Out:
#                          Market  No_of_Orders    Profit      Sales
# Region
# Southern Africa          Africa            85  11768.58   51319.50
# North Africa             Africa           182  21643.08   86698.89
# Eastern Africa           Africa           110   8013.04   44182.60
# Central Africa           Africa           103  15606.30   61689.99
# Southern Asia      Asia Pacific           469  67998.76  351806.60
# Southeastern Asia  Asia Pacific           533  20948.84  329751.38
# Oceania            Asia Pacific           646  54734.02  408002.98
# Eastern Asia       Asia Pacific           414  72805.10  315390.77
# Western Europe           Europe           964  82091.27  656637.14
# Southern Europe          Europe           338  18911.49  215703.93
# Northern Europe          Europe           367  43237.44  252969.09
# Eastern Europe           Europe           241  25050.69  108258.93
# South America             LATAM           496  12377.59  210710.49
# ...

# %%
#Count the positive profit
sales[sales[["Profit"]]>0].count()
# Out:
# Market           0
# No_of_Orders     0
# Profit          20
# Sales            0
# dtype: int64

# %%
sales

# %%
#Condition:sales>2lakh50000,market is european or latin american
sales[[sales["Sales"] > 250000 & (sales["Market"].isin(["LATAM","Europe"]))]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-0c93eae66001> in <cell line: 2>()
#       1 #Condition:sales>2lakh50000,market is european or latin american
# ----> 2 sales[[sales["Sales"] > 250000 & (sales["Market"].isin(["LATAM","Europe"]))]]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#Condition:sales>2lakh50000,market is european or latin american
sales[[sales["Sales"] > 250000 & (sales["Market"] == "Europe" or sales["Market"] == "LATAM")]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-5c319b835f59> in <cell line: 2>()
#       1 #Condition:sales>2lakh50000,market is european or latin american
# ----> 2 sales[[sales["Sales"] > 250000 & (sales["Market"] == "Europe" or sales["Market"] == "LATAM")]]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#Change each value of sales into thousands
sales.Sales=sales.Sales.floordiv(1000)
sales
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-67ea2e611873> in <cell line: 2>()
#       1 #Change each value of sales into thousands
# ----> 2 sales.Sales=sales.Sales.floordiv(1000)
#       3 sales
#
# AttributeError: 'NoneType' object has no attribute 'Sales'

# %%
sales.rename({"Sales":"Sales in thousand"}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-0bc65444c024> in <cell line: 1>()
# ----> 1 sales.rename({"Sales":"Sales in thousand"}, inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'rename'

# %%
print(sales)
# Out:
# None
